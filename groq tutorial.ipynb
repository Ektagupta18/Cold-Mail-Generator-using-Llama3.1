# %%
# %pip install langchain
# Out:
# Collecting langchain
#   Downloading langchain-0.3.3-py3-none-any.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.10 in c:\users\ekta gupta\anaconda\lib\site-packages (from langchain) (0.3.10)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\ekta gupta\anaconda\lib\site-packages (from langchain) (6.0)
# Collecting langchain-text-splitters<0.4.0,>=0.3.0
#   Downloading langchain_text_splitters-0.3.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\ekta gupta\anaconda\lib\site-packages (from langchain) (8.5.0)
# Requirement already satisfied: numpy<2,>=1 in c:\users\ekta gupta\anaconda\lib\site-packages (from langchain) (1.23.5)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\ekta gupta\anaconda\lib\site-packages (from langchain) (1.4.39)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\ekta gupta\anaconda\lib\site-packages (from langchain) (4.0.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\ekta gupta\anaconda\lib\site-packages (from langchain) (0.1.133)
# Requirement already satisfied: requests<3,>=2 in c:\users\ekta gupta\anaconda\lib\site-packages (from langchain) (2.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ekta gupta\anaconda\lib\site-packages (from langchain) (2.9.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\ekta gupta\anaconda\lib\site-packages (from langchain) (3.8.5)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ekta gupta\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ekta gupta\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ekta gupta\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\ekta gupta\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.2)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\ekta gupta\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ekta gupta\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\ekta gupta\anaconda\lib\site-packages (from langchain-core<0.4.0,>=0.3.10->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\ekta gupta\anaconda\lib\site-packages (from langchain-core<0.4.0,>=0.3.10->langchain) (4.12.2)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\ekta gupta\anaconda\lib\site-packages (from langchain-core<0.4.0,>=0.3.10->langchain) (24.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\ekta gupta\anaconda\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\ekta gupta\anaconda\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ekta gupta\anaconda\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\ekta gupta\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ekta gupta\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ekta gupta\anaconda\lib\site-packages (from requests<3,>=2->langchain) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ekta gupta\anaconda\lib\site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ekta gupta\anaconda\lib\site-packages (from requests<3,>=2->langchain) (2022.12.7)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ekta gupta\anaconda\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.1)
# Requirement already satisfied: anyio in c:\users\ekta gupta\anaconda\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (3.5.0)
# Requirement already satisfied: sniffio in c:\users\ekta gupta\anaconda\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\ekta gupta\anaconda\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ekta gupta\anaconda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ekta gupta\anaconda\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.10->langchain) (2.1)
# Installing collected packages: langchain-text-splitters, langchain
# Successfully installed langchain-0.3.3 langchain-text-splitters-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -qU langchain-groq
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import getpass
import os

if "GROQ_API_KEY" not in os.environ:
    os.environ["GROQ_API_KEY"] = getpass.getpass("Enter your Groq API key: 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 ")

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="mixtral-8x7b-32768",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
    # other params...
)

# %%
# %pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-0.5.12-py3-none-any.whl (602 kB)
#      -------------------------------------- 602.6/602.6 kB 1.1 MB/s eta 0:00:00
# Collecting posthog>=2.4.0
#   Downloading posthog-3.7.0-py2.py3-none-any.whl (54 kB)
#      ---------------------------------------- 54.4/54.4 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\ekta gupta\anaconda\lib\site-packages (from chromadb) (4.12.2)
# Collecting kubernetes>=28.1.0
#   Downloading kubernetes-31.0.0-py2.py3-none-any.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 1.6 MB/s eta 0:00:00
# Collecting importlib-resources
#   Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Collecting fastapi>=0.95.2
#   Downloading fastapi-0.115.0-py3-none-any.whl (94 kB)
#      ---------------------------------------- 94.6/94.6 kB 5.3 MB/s eta 0:00:00
# Collecting typer>=0.9.0
#   Downloading typer-0.12.5-py3-none-any.whl (47 kB)
#      ---------------------------------------- 47.3/47.3 kB ? eta 0:00:00
# Collecting opentelemetry-sdk>=1.2.0
#   Downloading opentelemetry_sdk-1.27.0-py3-none-any.whl (110 kB)
#      -------------------------------------- 110.5/110.5 kB 3.2 MB/s eta 0:00:00
# Collecting tokenizers>=0.13.2
#   Downloading tokenizers-0.20.1-cp310-none-win_amd64.whl (2.4 MB)
#      ---------------------------------------- 2.4/2.4 MB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\ekta gupta\anaconda\lib\site-packages (from chromadb) (8.5.0)
# Collecting pypika>=0.48.9
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ---------------------------------------- 67.3/67.3 kB 3.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: orjson>=3.9.12 in c:\users\ekta gupta\anaconda\lib\site-packages (from chromadb) (3.10.7)
# Collecting tqdm>=4.65.0
#   Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.4/78.4 kB 2.2 MB/s eta 0:00:00
# Collecting opentelemetry-api>=1.2.0
#   Downloading opentelemetry_api-1.27.0-py3-none-any.whl (63 kB)
#      ---------------------------------------- 64.0/64.0 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\ekta gupta\anaconda\lib\site-packages (from chromadb) (6.0)
# Collecting mmh3>=4.0.1
#   Downloading mmh3-5.0.1-cp310-cp310-win_amd64.whl (39 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0
#   Downloading opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl (11 kB)
# Collecting overrides>=7.3.1
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting build>=1.0.3
#   Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Collecting onnxruntime>=1.14.1
#   Downloading onnxruntime-1.19.2-cp310-cp310-win_amd64.whl (11.1 MB)
#      ---------------------------------------- 11.1/11.1 MB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: httpx>=0.27.0 in c:\users\ekta gupta\anaconda\lib\site-packages (from chromadb) (0.27.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\ekta gupta\anaconda\lib\site-packages (from chromadb) (1.66.1)
# Requirement already satisfied: pydantic>=1.9 in c:\users\ekta gupta\anaconda\lib\site-packages (from chromadb) (2.9.2)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.27.0-py3-none-any.whl (18 kB)
# Collecting chroma-hnswlib==0.7.6
#   Downloading chroma_hnswlib-0.7.6-cp310-cp310-win_amd64.whl (150 kB)
#      -------------------------------------- 151.0/151.0 kB 1.5 MB/s eta 0:00:00
# Collecting uvicorn[standard]>=0.18.3
#   Downloading uvicorn-0.31.1-py3-none-any.whl (63 kB)
#      ---------------------------------------- 63.7/63.7 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22.5 in c:\users\ekta gupta\anaconda\lib\site-packages (from chromadb) (1.23.5)
# Requirement already satisfied: rich>=10.11.0 in c:\users\ekta gupta\anaconda\lib\site-packages (from chromadb) (13.3.5)
# Collecting bcrypt>=4.0.1
#   Downloading bcrypt-4.2.0-cp39-abi3-win_amd64.whl (151 kB)
#      -------------------------------------- 151.7/151.7 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: tomli>=1.1.0 in c:\users\ekta gupta\anaconda\lib\site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Collecting pyproject_hooks
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: colorama in c:\users\ekta gupta\anaconda\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: packaging>=19.1 in c:\users\ekta gupta\anaconda\lib\site-packages (from build>=1.0.3->chromadb) (24.1)
# Collecting starlette<0.39.0,>=0.37.2
#   Downloading starlette-0.38.6-py3-none-any.whl (71 kB)
#      ---------------------------------------- 71.5/71.5 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in c:\users\ekta gupta\anaconda\lib\site-packages (from httpx>=0.27.0->chromadb) (1.2.0)
# Requirement already satisfied: certifi in c:\users\ekta gupta\anaconda\lib\site-packages (from httpx>=0.27.0->chromadb) (2022.12.7)
# Requirement already satisfied: anyio in c:\users\ekta gupta\anaconda\lib\site-packages (from httpx>=0.27.0->chromadb) (3.5.0)
# Requirement already satisfied: idna in c:\users\ekta gupta\anaconda\lib\site-packages (from httpx>=0.27.0->chromadb) (3.4)
# Requirement already satisfied: httpcore==1.* in c:\users\ekta gupta\anaconda\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ekta gupta\anaconda\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\ekta gupta\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.26.14)
# Requirement already satisfied: six>=1.9.0 in c:\users\ekta gupta\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Collecting durationpy>=0.7
#   Downloading durationpy-0.9-py3-none-any.whl (3.5 kB)
# Collecting oauthlib>=3.2.2
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      -------------------------------------- 151.7/151.7 kB 3.0 MB/s eta 0:00:00
# Collecting google-auth>=1.0.1
#   Downloading google_auth-2.35.0-py2.py3-none-any.whl (208 kB)
#      -------------------------------------- 209.0/209.0 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\ekta gupta\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.28.1)
# Collecting requests-oauthlib
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\ekta gupta\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\ekta gupta\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: protobuf in c:\users\ekta gupta\anaconda\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: sympy in c:\users\ekta gupta\anaconda\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.11.1)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ---------------------------------------- 46.0/46.0 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in c:\users\ekta gupta\anaconda\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Collecting importlib-metadata<=8.4.0,>=6.0
#   Downloading importlib_metadata-8.4.0-py3-none-any.whl (26 kB)
# Collecting deprecated>=1.2.6
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.27.0
#   Downloading opentelemetry_exporter_otlp_proto_common-1.27.0-py3-none-any.whl (17 kB)
# Collecting opentelemetry-proto==1.27.0
#   Downloading opentelemetry_proto-1.27.0-py3-none-any.whl (52 kB)
#      ---------------------------------------- 52.5/52.5 kB 2.6 MB/s eta 0:00:00
# Collecting googleapis-common-protos~=1.52
#   Downloading googleapis_common_protos-1.65.0-py2.py3-none-any.whl (220 kB)
#      -------------------------------------- 220.9/220.9 kB 6.8 MB/s eta 0:00:00
# Collecting opentelemetry-instrumentation-asgi==0.48b0
#   Downloading opentelemetry_instrumentation_asgi-0.48b0-py3-none-any.whl (15 kB)
# Collecting opentelemetry-semantic-conventions==0.48b0
#   Downloading opentelemetry_semantic_conventions-0.48b0-py3-none-any.whl (149 kB)
#      -------------------------------------- 149.7/149.7 kB 3.0 MB/s eta 0:00:00
# Collecting opentelemetry-util-http==0.48b0
#   Downloading opentelemetry_util_http-0.48b0-py3-none-any.whl (6.9 kB)
# Collecting opentelemetry-instrumentation==0.48b0
#   Downloading opentelemetry_instrumentation-0.48b0-py3-none-any.whl (29 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\ekta gupta\anaconda\lib\site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Requirement already satisfied: setuptools>=16.0 in c:\users\ekta gupta\anaconda\lib\site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (65.6.3)
# Collecting asgiref~=3.0
#   Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Collecting backoff>=1.10.0
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting monotonic>=1.5
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\ekta gupta\anaconda\lib\site-packages (from pydantic>=1.9->chromadb) (2.23.4)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ekta gupta\anaconda\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\ekta gupta\anaconda\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ekta gupta\anaconda\lib\site-packages (from rich>=10.11.0->chromadb) (2.15.1)
# Collecting huggingface-hub<1.0,>=0.16.4
#   Downloading huggingface_hub-0.25.2-py3-none-any.whl (436 kB)
#      -------------------------------------- 436.6/436.6 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: click>=8.0.0 in c:\users\ekta gupta\anaconda\lib\site-packages (from typer>=0.9.0->chromadb) (8.0.4)
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting websockets>=10.4
#   Downloading websockets-13.1-cp310-cp310-win_amd64.whl (159 kB)
#      -------------------------------------- 159.1/159.1 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\ekta gupta\anaconda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.0)
# Collecting watchfiles>=0.13
#   Downloading watchfiles-0.24.0-cp310-none-win_amd64.whl (277 kB)
#      -------------------------------------- 277.5/277.5 kB 2.4 MB/s eta 0:00:00
# Collecting httptools>=0.5.0
#   Downloading httptools-0.6.1-cp310-cp310-win_amd64.whl (58 kB)
#      ---------------------------------------- 58.2/58.2 kB ? eta 0:00:00
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ekta gupta\anaconda\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ekta gupta\anaconda\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.0)
# Requirement already satisfied: filelock in c:\users\ekta gupta\anaconda\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.9.0)
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#      -------------------------------------- 179.3/179.3 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in c:\users\ekta gupta\anaconda\lib\site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.11.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ekta gupta\anaconda\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ekta gupta\anaconda\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (2.0.4)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ---------------------------------------- 86.8/86.8 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in c:\users\ekta gupta\anaconda\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.2.1)
# Collecting pyreadline3
#   Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
#      ---------------------------------------- 83.2/83.2 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\ekta gupta\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml): started
#   Building wheel for pypika (pyproject.toml): finished with status 'done'
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53834 sha256=821f0e01f878689a9425fa7d0d49954111f6c1c07124324a6e555f2649860818
#   Stored in directory: c:\users\ekta gupta\appdata\local\pip\cache\wheels\c4\41\b6\f76a356f0791da799545c23894ceae842eeff054d0eb1fb626
# Successfully built pypika
# Installing collected packages: pypika, monotonic, durationpy, websockets, tqdm, shellingham, rsa, pyreadline3, pyproject_hooks, overrides, opentelemetry-util-http, opentelemetry-proto, oauthlib, mmh3, importlib-resources, importlib-metadata, httptools, googleapis-common-protos, fsspec, deprecated, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, uvicorn, starlette, requests-oauthlib, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, humanfriendly, huggingface-hub, google-auth, build, typer, tokenizers, opentelemetry-semantic-conventions, opentelemetry-instrumentation, kubernetes, fastapi, coloredlogs, opentelemetry-sdk, opentelemetry-instrumentation-asgi, onnxruntime, opentelemetry-instrumentation-fastapi, opentelemetry-exporter-otlp-proto-grpc, chromadb
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.1
#     Uninstalling tqdm-4.64.1:
#       Successfully uninstalled tqdm-4.64.1
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.11.3
#     Uninstalling importlib-metadata-4.11.3:
#       Successfully uninstalled importlib-metadata-4.11.3
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2022.11.0
#     Uninstalling fsspec-2022.11.0:
#       Successfully uninstalled fsspec-2022.11.0
#   Attempting uninstall: bcrypt
#     Found existing installation: bcrypt 3.2.0
#     Uninstalling bcrypt-3.2.0:
#       Successfully uninstalled bcrypt-3.2.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.10.1
#     Uninstalling huggingface-hub-0.10.1:
#       Successfully uninstalled huggingface-hub-0.10.1
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.11.4
#     Uninstalling tokenizers-0.11.4:
#       Successfully uninstalled tokenizers-0.11.4
# Successfully installed asgiref-3.8.1 backoff-2.2.1 bcrypt-4.2.0 build-1.2.2.post1 chroma-hnswlib-0.7.6 chromadb-0.5.12 coloredlogs-15.0.1 deprecated-1.2.14 durationpy-0.9 fastapi-0.115.0 fsspec-2024.9.0 google-auth-2.35.0 googleapis-common-protos-1.65.0 httptools-0.6.1 huggingface-hub-0.25.2 humanfriendly-10.0 importlib-metadata-8.4.0 importlib-resources-6.4.5 kubernetes-31.0.0 mmh3-5.0.1 monotonic-1.6 oauthlib-3.2.2 onnxruntime-1.19.2 opentelemetry-api-1.27.0 opentelemetry-exporter-otlp-proto-common-1.27.0 opentelemetry-exporter-otlp-proto-grpc-1.27.0 opentelemetry-instrumentation-0.48b0 opentelemetry-instrumentation-asgi-0.48b0 opentelemetry-instrumentation-fastapi-0.48b0 opentelemetry-proto-1.27.0 opentelemetry-sdk-1.27.0 opentelemetry-semantic-conventions-0.48b0 opentelemetry-util-http-0.48b0 overrides-7.7.0 posthog-3.7.0 pypika-0.48.9 pyproject_hooks-1.2.0 pyreadline3-3.5.4 requests-oauthlib-2.0.0 rsa-4.9 shellingham-1.5.4 starlette-0.38.6 tokenizers-0.20.1 tqdm-4.66.5 typer-0.12.5 uvicorn-0.31.1 watchfiles-0.24.0 websockets-13.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 4.24.0 requires tokenizers!=0.11.3,<0.14,>=0.11.1, but you have tokenizers 0.20.1 which is incompatible.
